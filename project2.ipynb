# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %%
import bs4
import requests
import pandas as pd

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %%
![TextDisplayObject](Months.png)
#See attached image Months.png 

from bs4 import BeautifulSoup

# HTML with an anchor element
html_snippet = """
<th class="header_Sort" tabindex="0" role="columheader button"  title="Sort ascending">Year</th>
"""

soup = BeautifulSoup(html_snippet, 'html.parser')
th_element = soup.find('th')

class_name = th_element.get('class')
tab_index = th_element.get('tabindex')
role = th_element.get('role')
title = th_element.get("title")
header_text = th_element.get_text()

print("Class:", class_name)
print("Tabindex:", tab_index)
print("Role:", role)
print("Title:", title)
print("Header Text:", header_text)
# Out:
# zsh:1: unknown file attribute: h
# Class: ['header_Sort']
# Tabindex: 0
# Role: columheader button
# Title: Sort ascending
# Header Text: Year

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %%
from bs4 import BeautifulSoup

#HTML syntax for a link using inspect element
html_snippet = """
<a  href="https://en.wikipedia.org/wiki/Month" title="Month">Month</a>
"""

# %% [markdown]
# <a href="/wiki/March" title="March">March</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %%
from bs4 import BeautifulSoup

#HTML syntax for linking an image
html_snippet = """
<a href="https://en.wikipedia.org/wiki/Jesus">
<img alt="A Nativity scene; men and animals surround Mary and newborn Jesus, who are covered in light" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg/220px-Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg" decoding="async" width="220" height="181" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg/330px-Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/05/Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg/440px-Gerard_van_Honthorst_-_Adoration_of_the_Shepherds_%281622%29.jpg 2x" data-file-width="2057" data-file-height="1690">
</a>
"""

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Jesus'
response = requests.get('https://en.wikipedia.org/wiki/Jesus')
response
# Out:
# <Response [200]>

# %%
wiki = response.text
wiki
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Jesus - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-fea
# ...

# %%
#save and print the text content of a page with all tags removed
soup = BeautifulSoup(wiki, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Jesus - Wikipedia</title>
# ...

# %%
#download an image with beautifulsoup and save it in this repository

import requests 

from bs4 import BeautifulSoup

r = requests.get("https://en.wikipedia.org/wiki/File:Spas_vsederzhitel_sinay_(cropped1).jpg")

soup = BeautifulSoup(r.content)
print(soup.prettify()) 

images = soup.select('div img') 

images_url = images[0]['src'] 

images_url
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref--excluded vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-not-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    File:Spas vsederzhitel sinay (cropped1).jpg - Wikipedia
#   </title>
#   <script>
# ...

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links

def find_links(url):
    page =  requests.get(url)

    if page.status_code == 200:
        soup =  bs4.BeautifulSoup(page.content, 'html.parser')
        links = soup.find_all('a')

        for i in range(min(10, len(links))):
            if 'href' in links[i].attrs:
                print(links[i]['href'][:100])
    else: 
        print(f"Failed to retrieve page. Status code: {page.status_code}")

url = "https://en.wikipedia.org/wiki/Jesus"
find_links(url)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags

import requests 
from bs4 import BeautifulSoup

def download_script_text(url):
    
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.get_text()
    except:
        return ""

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"

scripts["text"]=scripts["link"].apply(download_script_text)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ...

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 

key = '4691d46e169d51c554f23b91577e8d67'
token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0NjkxZDQ2ZTE2OWQ1MWM1NTRmMjNiOTE1NzdlOGQ2NyIsIm5iZiI6MTcyODQ5MzQwMC42ODg1ODYsInN1YiI6IjY2ZmRhMDA0ZTQ4MDE0OTE0Njg0YjNiZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.JhpunT1u31x9MPBc5aqo6Xd_6GPlr2Vjzpo_PN1Yp1E'


url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

#TMDB wants you to authenticate to show that you have and account and control access
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0NjkxZDQ2ZTE2OWQ1MWM1NTRmMjNiOTE1NzdlOGQ2NyIsIm5iZiI6MTcyODQ5MzQwMC42ODg1ODYsInN1YiI6IjY2ZmRhMDA0ZTQ4MDE0OTE0Njg0YjNiZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.JhpunT1u31x9MPBc5aqo6Xd_6GPlr2Vjzpo_PN1Yp1E"
}


response = requests.get(url, headers=headers)
response
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/yDHYTfA3R0jFYba16jBB1ef8oIt.jpg',
#    'genre_ids': [28, 35, 878],
#    'id': 533535,
#    'original_language': 'en',
#    'original_title': 'Deadpool & Wolverine',
#    'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.',
#    'popularity': 3546.58,
#    'poster_path': '/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg',
#    'release_date': '2024-07-24',
#    'title': 'Deadpool & Wolverine',
#    'video': False,
#    'vote_average': 7.732,
#    'vote_count': 4173},
#   {'adult': False,
#    'backdrop_path': '/7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg',
#    'genre_ids': [27, 35, 18],
#    'id': 933260,
#    'original_language': 'en',
#    'original_title': 'The Substance',
# ...

# %%
dict=response.json()
movies_df = pd.DataFrame(dict["results"])

# %%
src = "https://media.themoviedb.org/t/p/w300_and_h450_bestv2"

# %%
movies_df["url"] = src + movies_df["poster_path"]

# %%
movies_df
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg            [28, 35, 878]   533535
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [27, 35, 18]   933260
# 2   False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]   519182
# 3   False  /hPIWQT70wQK6akqfLXByEvr62u0.jpg        [28, 53, 27, 878]   726139
# 4   False  /tCKWksaQI8XkAQLVou0AlGab5S6.jpg                [28, 878]  1144962
# 5   False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg                 [27, 53]  1114513
# 6   False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg             [35, 14, 27]   917496
# 7   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg     [28, 14, 27, 53, 80]   957452
# 8   False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
# 9   False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg         [16, 878, 10751]  1184918
# 10  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg             [18, 80, 53]   889737
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository

for i in  movies_df["url"]:
    print(i)
# Out:
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/lqoMzCcZYEFK729d6qzt349fB4o.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/wWba3TaojhK7NdycRhoQpsG0FaH.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/fttoFfKikQMwIoV3UVvlCvBhbUw.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/oqhaffnQqSzdLrYAQA5W4IdAoCX.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg
# https://media.themoviedb.org/t/p/w300_and_h450_bestv2/if8QiqCI7WAGImKcJCfzp6VTyKA.jpg
# ...

# %%
import requests
import shutil

for url in movies_df["url"]:
    img_data=requests.get(url).content

    filename = url.split("/")[-1]
    r = requests.get(url, timeout=0.5)

    if r.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(r.content)
